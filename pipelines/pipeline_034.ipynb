# %% [markdown]
# Testing completed_data_C02__01.csv

# %% [markdown]
# Since we are dealing with an unbalanced dataset, it is recommended to use other metrics instead of accuracy.
#
# In this case we propose to use AUC (*Area Under the Curve*) which is a measure of the classifier's ability to distinguish between classes and is used as a representation of the ROC curve. The higher the AUC, the better the performance of the model in distinguishing between the positive and negative classes.
#
# A ROC curve (*receiver operating characteristic curve*) is a graph that shows the performance of a classification model at all classification thresholds. This curve plots two parameters: *True Positive Rate* (TPR) and *False Positive Rate* (FPR)
# - TPR = TP / (TP + FN)
# - FPR = FP / (FP + TN)
#
# TPR vs. FPR are plotted at different classification thresholds. Lowering the classification threshold classifies more items as positives, which increases both false positives and true positives. The following figure shows a typical ROC curve.

# %%
from sklearn.model_selection import (
    TimeSeriesSplit,
    KFold,
    StratifiedKFold,
    GroupKFold,
    StratifiedGroupKFold
)

# %%
import matplotlib.pylab as plt
from matplotlib.patches import Patch
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
plt.style.use('seaborn-white')

cmap_data = plt.cm.Paired
cmap_cv = plt.cm.coolwarm

def visualize_groups(classes, groups, name):
    # Visualize dataset groups
    fig, ax = plt.subplots()
    ax.scatter(
        range(len(groups)),
        [0.5] * len(groups),
        c=groups,
        marker="_",
        lw=50,
        cmap=cmap_data,
    )
    ax.scatter(
        range(len(groups)),
        [3.5] * len(groups),
        c=classes,
        marker="_",
        lw=50,
        cmap=cmap_data,
    )
    ax.set(
        ylim=[-1, 5],
        yticks=[0.5, 3.5],
        yticklabels=["Data\ngroup", "Data\nclass"],
        xlabel="Sample index",
    )


def plot_cv_indices(cv, X, y, group, ax, n_splits, lw=25):
    """Create a sample plot for indices of a cross-validation object."""

    # Generate the training/testing visualizations for each CV split
    for ii, (tr, tt) in enumerate(cv.split(X=X, y=y, groups=group)):
        # Fill in indices with the training/test groups
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        # Visualize the results
        ax.scatter(
            range(len(indices)),
            [ii + 0.5] * len(indices),
            c=indices,
            marker="_",
            lw=lw,
            cmap=cmap_cv,
            vmin=-0.2,
            vmax=1.2,
        )

    # Plot the data classes and groups at the end
    ax.scatter(
        range(len(X)), [ii + 1.5] * len(X), c=y, marker="_", lw=lw, cmap=cmap_data
    )

    ax.scatter(
        range(len(X)), [ii + 2.5] * len(X), c=group, marker="_", lw=lw, cmap=cmap_data
    )

    # Formatting
    yticklabels = list(range(n_splits)) + ["class", "group"]
    ax.set(
        yticks=np.arange(n_splits + 2) + 0.5,
        yticklabels=yticklabels,
        xlabel="Sample index",
        ylabel="CV iteration",
        ylim=[n_splits + 2.2, -0.2],
        xlim=[0, X.shape[0]],
    )
    ax.set_title("{}".format(type(cv).__name__), fontsize=15)
    return ax


def plot_cv(cv, X, y, groups, n_splits=5):
    this_cv = cv(n_splits=n_splits)
    fig, ax = plt.subplots(figsize=(15, 5))
    plot_cv_indices(this_cv, X, y, groups, ax, n_splits)

    ax.legend(
        [Patch(color=cmap_cv(0.8)), Patch(color=cmap_cv(0.02))],
        ["Testing set", "Training set"],
        loc=(1.02, 0.8),
    )
    plt.tight_layout()
    fig.subplots_adjust(right=0.7)
    plt.show()
    
def get_X_y():
    # Fake Generate the class/group data for an example
    df_normalized = pd.read_csv('../autocomplete_data/completed_data__C02__01.csv') 
    df_normalized= df_normalized.dropna()
   
    
    print(df_normalized.shape)
    X = df_normalized.drop('estado_vital', axis=1)
    y = df_normalized['estado_vital']
    X_tr, X_val, y_tr, y_val = train_test_split(X, y, test_size=0.1)
    pca=PCA(int(df_normalized.shape[1]/2))
    pca.fit_transform(X_tr,y_tr)
    GROUPS = "edad"
    groups = pd.cut(df_normalized[GROUPS], bins=5, labels=False)
    return X, y, groups
# Out:
# /var/folders/kg/hcvz64bd4xxfycd8h1j194z40000gn/T/ipykernel_8941/766083361.py:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, roc_auc_score

kf = KFold()
X, y, groups= get_X_y()
plot_cv(KFold, X, y,groups)
skf = StratifiedKFold()
X_, y_, groups= get_X_y()
plot_cv(StratifiedKFold, X_, y_,groups)
# Out:
# (1256, 63)
# (1256, 63)

# %%
X_tr, X_val, y_tr, y_val = train_test_split(X, y, test_size=0.1)
svc=SVC(kernel='rbf',probability=True)
svc.fit(X_tr,y_tr)
y_res=svc.predict(X_val)
y_res_prob=svc.predict_proba(X_val)[:,1]
acc_score = accuracy_score(y_val,y_res)
auc_score = roc_auc_score(y_val,y_res_prob)
print(f"Accuracy: {acc_score:0.4f}")
print(f"AUC: {auc_score:0.4f}")
# Out:
# Accuracy: 0.8571
# AUC: 0.6831

# %%
gskf = StratifiedGroupKFold()
X_, y_,groups = get_X_y()
np.random.shuffle(y_)
plot_cv(StratifiedGroupKFold, X_, y_, groups)
# Out:
# (1256, 63)
# /var/folders/kg/hcvz64bd4xxfycd8h1j194z40000gn/T/ipykernel_8941/2934433308.py:3: UserWarning: you are shuffling a 'Series' object which is not a subclass of 'Sequence'; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   np.random.shuffle(y_)

# %%
gkf = GroupKFold()
X_, y_, groups_ = get_X_y()
plot_cv(GroupKFold, X_, y_, groups_)
# Out:
# (1256, 63)

# %%
gskf = StratifiedGroupKFold()
X_, y_, groups_ = get_X_y()
np.random.shuffle(y_)
plot_cv(StratifiedGroupKFold, X_, y_, groups_)
# Out:
# (1256, 63)
# /var/folders/kg/hcvz64bd4xxfycd8h1j194z40000gn/T/ipykernel_8941/2097765019.py:3: UserWarning: you are shuffling a 'Series' object which is not a subclass of 'Sequence'; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   np.random.shuffle(y_)

# %%
tss = TimeSeriesSplit()
X_, y_, groups_ = get_X_y()
plot_cv(TimeSeriesSplit, X_, y_, groups_)
# Out:
# (1256, 63)

# %%
def train_with_cv(clf, cv=StratifiedKFold):
    sgk = cv(n_splits=5, shuffle=True, random_state=30)
    X, y, groups = get_X_y()

    fold = 0
    aucs = []
    for train_idx, val_idx in sgk.split(X, y, groups):
        X_tr = X.loc[train_idx]
        y_tr = y.loc[train_idx]

        X_val = X.loc[val_idx]
        y_val = y.loc[val_idx]

        # Fit Model on Train
        auc_score=None
        clf.fit(X_tr, y_tr)
        pred = clf.predict_proba(X_val)[:,1]
        try:
            auc_score = roc_auc_score(y_val, pred)
        except ValueError:
            pass
        if auc_score is not None:
            print(f"======= Fold {fold} ========")
            print(
                f"El AUC en el conjunto de validación es {auc_score:0.4f}"
            )
        fold += 1
        aucs.append(auc_score)
    oof_auc = np.mean(aucs)
    print(f'El resultado AUC promediado es {oof_auc:0.4f}')

# %%
train_with_cv(svc)
# Out:
# (1256, 63)
# ======= Fold 0 ========
# El AUC en el conjunto de validación es 0.5780
# ======= Fold 1 ========
# El AUC en el conjunto de validación es 0.7765
# ======= Fold 2 ========
# El AUC en el conjunto de validación es 0.7229
# ======= Fold 3 ========
# El AUC en el conjunto de validación es 0.7517
# ======= Fold 4 ========
# El AUC en el conjunto de validación es 0.6720
# El resultado AUC promediado es 0.7002

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import HistGradientBoostingClassifier

clf1 = GradientBoostingClassifier(n_estimators=62, learning_rate=1,max_depth=3, random_state=5)
clf2 = HistGradientBoostingClassifier(min_samples_leaf=12)

train_with_cv(clf1)
train_with_cv(clf2)
# Out:
# (1256, 63)
# ======= Fold 0 ========
# El AUC en el conjunto de validación es 0.8576
# ======= Fold 1 ========
# El AUC en el conjunto de validación es 0.9396
# ======= Fold 2 ========
# El AUC en el conjunto de validación es 0.8024
# ======= Fold 3 ========
# El AUC en el conjunto de validación es 0.8089
# ======= Fold 4 ========
# El AUC en el conjunto de validación es 0.9415
# El resultado AUC promediado es 0.8700
# (1256, 63)
# ======= Fold 0 ========
# El AUC en el conjunto de validación es 0.8967
# ======= Fold 1 ========
# El AUC en el conjunto de validación es 0.9537
# ======= Fold 2 ========
# El AUC en el conjunto de validación es 0.9230
# ======= Fold 3 ========
# El AUC en el conjunto de validación es 0.8949
# ======= Fold 4 ========
# El AUC en el conjunto de validación es 0.9643
# El resultado AUC promediado es 0.9265

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
# dataset=pd.read_csv("data_cleaned.csv")
# Create X and y
# X = df.drop("estado_vital", axis=1)
# y= df["estado_vital"]
gskf = StratifiedGroupKFold()
X_, y_, groups_ = get_X_y()
# Split fata into train and ttest
np.random.seed(46)
#standardScaler = StandardScaler()
#columns_to_scale = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
#dataset[columns_to_scale] = standardScaler.fit_transform(dataset[columns_to_scale])
# X=dataset.iloc[:,0:13]
# y=dataset.iloc[:,13:14]


# from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_,y_,test_size=0.20,random_state=30)

ss=StandardScaler()
X_train=ss.fit_transform(X_train)
X_test=ss.fit_transform(X_test)


from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Dropout

#Creating a pipeline
model = Sequential()

#1st hidden layer with input layer
model.add(Dense(units=62,activation="relu",input_dim=62)) #59

#2nd hidden layer
model.add(Dense(units=32,activation="relu",))

# #2nd hidden layer
# model.add(Dense(units=30,activation="relu",))

# #3rd hidden layer
# model.add(Dense(units=14,activation="relu",))

#4th hidden layer
model.add(Dense(units=12,activation="relu",))



#output layer
model.add(Dense(units=1,activation="sigmoid"))

model.summary()
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
model_his=model.fit(X_train,y_train,validation_split=0.20, batch_size=35,epochs=50,verbose=1)


y_pred=model.predict(X_test)
y_pred = (y_pred > 0.45)

from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
print(score)

from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(y_test, y_pred)
print(cm)


print(classification_report(y_test,y_pred))


import matplotlib.pyplot as plt
# summarize history for accuracy
plt.plot(model_his.history['accuracy'])
plt.plot(model_his.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


# summarize history for loss
plt.plot(model_his.history['loss'])
plt.plot(model_his.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()



#model.save("heart.h5")
# Out:
# (1256, 63)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 62)                3906
#
#  dense_9 (Dense)             (None, 32)                2016
#
#  dense_10 (Dense)            (None, 12)                396
#
#  dense_11 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 6331 (24.73 KB)
# Trainable params: 6331 (24.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4743 - accuracy: 0.8555 - val_loss: 0.2991 - val_accuracy: 0.9104
# Epoch 2/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.9128 - val_loss: 0.2148 - val_accuracy: 0.9055
# Epoch 3/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2053 - accuracy: 0.9141 - val_loss: 0.1869 - val_accuracy: 0.9154
# Epoch 4/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1686 - accuracy: 0.9315 - val_loss: 0.1723 - val_accuracy: 0.9204
# Epoch 5/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1432 - accuracy: 0.9402 - val_loss: 0.1631 - val_accuracy: 0.9303
# Epoch 6/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1223 - accuracy: 0.9489 - val_loss: 0.1596 - val_accuracy: 0.9353
# Epoch 7/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.1029 - accuracy: 0.9564 - val_loss: 0.1612 - val_accuracy: 0.9254
# Epoch 8/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0867 - accuracy: 0.9676 - val_loss: 0.1692 - val_accuracy: 0.9204
# Epoch 9/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0712 - accuracy: 0.9776 - val_loss: 0.1798 - val_accuracy: 0.9154
# Epoch 10/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0597 - accuracy: 0.9826 - val_loss: 0.1833 - val_accuracy: 0.9254
# Epoch 11/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0479 - accuracy: 0.9888 - val_loss: 0.1963 - val_accuracy: 0.9204
# Epoch 12/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9913 - val_loss: 0.2114 - val_accuracy: 0.9154
# Epoch 13/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0313 - accuracy: 0.9950 - val_loss: 0.2266 - val_accuracy: 0.9154
# Epoch 14/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 0.9963 - val_loss: 0.2307 - val_accuracy: 0.9104
# Epoch 15/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.9963 - val_loss: 0.2466 - val_accuracy: 0.9154
# Epoch 16/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9975 - val_loss: 0.2642 - val_accuracy: 0.9154
# Epoch 17/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9975 - val_loss: 0.2736 - val_accuracy: 0.9154
# Epoch 18/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.9975 - val_loss: 0.2832 - val_accuracy: 0.9154
# Epoch 19/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 0.9975 - val_loss: 0.2894 - val_accuracy: 0.9104
# Epoch 20/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.9988 - val_loss: 0.3037 - val_accuracy: 0.9104
# Epoch 21/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.9988 - val_loss: 0.3057 - val_accuracy: 0.9104
# Epoch 22/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.3197 - val_accuracy: 0.9055
# Epoch 23/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.3294 - val_accuracy: 0.9104
# Epoch 24/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.3361 - val_accuracy: 0.9104
# Epoch 25/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3445 - val_accuracy: 0.9104
# Epoch 26/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.3531 - val_accuracy: 0.9104
# Epoch 27/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3622 - val_accuracy: 0.9104
# Epoch 28/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3696 - val_accuracy: 0.9055
# Epoch 29/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3778 - val_accuracy: 0.9055
# Epoch 30/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3831 - val_accuracy: 0.9055
# Epoch 31/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3902 - val_accuracy: 0.9055
# Epoch 32/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3946 - val_accuracy: 0.9055
# Epoch 33/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4034 - val_accuracy: 0.9055
# Epoch 34/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4087 - val_accuracy: 0.9055
# Epoch 35/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4149 - val_accuracy: 0.9055
# Epoch 36/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4192 - val_accuracy: 0.9055
# Epoch 37/50
# 23/23 [==============================] - 0s 2ms/step - loss: 9.3617e-04 - accuracy: 1.0000 - val_loss: 0.4231 - val_accuracy: 0.9055
# Epoch 38/50
# 23/23 [==============================] - 0s 2ms/step - loss: 8.6802e-04 - accuracy: 1.0000 - val_loss: 0.4300 - val_accuracy: 0.9055
# Epoch 39/50
# 23/23 [==============================] - 0s 2ms/step - loss: 8.0785e-04 - accuracy: 1.0000 - val_loss: 0.4349 - val_accuracy: 0.9055
# Epoch 40/50
# 23/23 [==============================] - 0s 2ms/step - loss: 7.4467e-04 - accuracy: 1.0000 - val_loss: 0.4393 - val_accuracy: 0.9055
# Epoch 41/50
# 23/23 [==============================] - 0s 2ms/step - loss: 6.9159e-04 - accuracy: 1.0000 - val_loss: 0.4435 - val_accuracy: 0.9055
# Epoch 42/50
# 23/23 [==============================] - 0s 2ms/step - loss: 6.4911e-04 - accuracy: 1.0000 - val_loss: 0.4474 - val_accuracy: 0.9055
# Epoch 43/50
# 23/23 [==============================] - 0s 2ms/step - loss: 6.0334e-04 - accuracy: 1.0000 - val_loss: 0.4525 - val_accuracy: 0.9055
# Epoch 44/50
# 23/23 [==============================] - 0s 2ms/step - loss: 5.6576e-04 - accuracy: 1.0000 - val_loss: 0.4562 - val_accuracy: 0.9055
# Epoch 45/50
# 23/23 [==============================] - 0s 2ms/step - loss: 5.3230e-04 - accuracy: 1.0000 - val_loss: 0.4596 - val_accuracy: 0.9055
# Epoch 46/50
# 23/23 [==============================] - 0s 2ms/step - loss: 4.9916e-04 - accuracy: 1.0000 - val_loss: 0.4650 - val_accuracy: 0.9055
# Epoch 47/50
# 23/23 [==============================] - 0s 2ms/step - loss: 4.6720e-04 - accuracy: 1.0000 - val_loss: 0.4678 - val_accuracy: 0.9055
# Epoch 48/50
# 23/23 [==============================] - 0s 2ms/step - loss: 4.3856e-04 - accuracy: 1.0000 - val_loss: 0.4709 - val_accuracy: 0.9055
# Epoch 49/50
# 23/23 [==============================] - 0s 2ms/step - loss: 4.1600e-04 - accuracy: 1.0000 - val_loss: 0.4741 - val_accuracy: 0.9055
# Epoch 50/50
# 23/23 [==============================] - 0s 2ms/step - loss: 3.8807e-04 - accuracy: 1.0000 - val_loss: 0.4778 - val_accuracy: 0.9055
# 8/8 [==============================] - 0s 653us/step
# 0.9246031746031746
# [[219   6]
#  [ 13  14]]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.97      0.96       225
#          1.0       0.70      0.52      0.60        27
#
#     accuracy                           0.92       252
#    macro avg       0.82      0.75      0.78       252
# weighted avg       0.92      0.92      0.92       252
