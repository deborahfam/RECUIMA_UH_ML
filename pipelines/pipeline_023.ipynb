# %% [markdown]
# Testing augmented_data_C01__03__F01.csv

# %% [markdown]
# Now, we will use an additional parameter in the Logistic Regression model where we indicate weight = "balanced" and with this the algorithm will be in charge of balancing the minority class during training

# %% [markdown]
# # Logistic Regression Classifier with balanced weights

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
import pandas as pd
from sklearn.model_selection import train_test_split

def print_results(y_test, pred_y):
    conf_matrix = confusion_matrix(y_test, pred_y)
    plt.figure(figsize=(12, 12))
    sns.heatmap(conf_matrix, xticklabels='Alive', yticklabels='Deceased', annot=True, fmt="d")
    plt.title("Confusion matrix")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.show()
    print (classification_report(y_test, pred_y))

# %%
df_normalized = pd.read_csv('data_cleaned.csv') 
df_normalized= df_normalized.dropna()
print(df_normalized.shape)
X = df_normalized.drop('estado_vital', axis=1)
y = df_normalized['estado_vital']
# class wights
class_weight = {0: 1, 1: len(y) / sum(y)}

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=5) # 80% training and 20% test
def run_model_balanced(X_train, X_test, y_train, y_test):
    clf = LogisticRegression(C=1.0,penalty='l2',random_state=1,solver="newton-cg",class_weight="balanced")
    clf.fit(X_train, y_train)
    return clf
 
model = run_model_balanced(X_train, X_test, y_train, y_test)
pred_y = model.predict(X_test)
print_results(y_test, pred_y)
# Out:
# (1353, 24)
#               precision    recall  f1-score   support
#
#            0       0.97      0.72      0.82       239
#            1       0.28      0.81      0.41        32
#
#     accuracy                           0.73       271
#    macro avg       0.62      0.76      0.62       271
# weighted avg       0.88      0.73      0.77       271

# %% [markdown]
# Now we will use an algorithm to reduce the majority class. We will do it using an algorithm that is similar to k-nearest neighbor to select which ones to eliminate

# %% [markdown]
# # Subsampling in the majority class

# %%
from imblearn.under_sampling import NearMiss
from collections import Counter
us = NearMiss(n_neighbors=3, version=2)
X_train_res, y_train_res = us.fit_resample(X_train, y_train)
def run_model(X_train, X_test, y_train, y_test):
    clf_base = LogisticRegression(C=1.0,penalty='l2',random_state=1,solver="newton-cg")
    clf_base.fit(X_train, y_train)
    return clf_base
print ("Distribution before resampling {}".format(Counter(y_train)))
print ("Distribution after resampling {}".format(Counter(y_train_res)))
 
model = run_model(X_train_res, X_test, y_train_res, y_test)
pred_y = model.predict(X_test)
print_results(y_test, pred_y)
# Out:
# Distribution before resampling Counter({0: 976, 1: 106})
# Distribution after resampling Counter({0: 106, 1: 106})
#               precision    recall  f1-score   support
#
#            0       0.93      0.34      0.50       239
#            1       0.14      0.81      0.24        32
#
#     accuracy                           0.40       271
#    macro avg       0.54      0.58      0.37       271
# weighted avg       0.84      0.40      0.47       271

# %% [markdown]
# We will create new “synthetic” samples of the minority class. Using RandomOverSampler

# %% [markdown]
# Now we will test a widely used technique that consists of simultaneously applying a subsampling algorithm and an oversampling algorithm to the dataset at the same time. In this case we will use SMOTE for oversampling: find nearby neighboring points and add points “in a straight line” between them. And we will use Tomek for undersampling that removes those of different classes that are nearest neighbors and lets us see better the decision boundary (the limit zone of our classes).

# %% [markdown]
# # Ensamble of models with BalancedBaggingClassifier

# %%
from imblearn.ensemble import BalancedBaggingClassifier
from sklearn.tree import DecisionTreeClassifier
bbc = BalancedBaggingClassifier(base_estimator=DecisionTreeClassifier(),
                                sampling_strategy='auto',
                                replacement=False,
                                random_state=0)
 
#Train the classifier.
bbc.fit(X_train, y_train)
pred_y = bbc.predict(X_test)
print_results(y_test, pred_y)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/imblearn/ensemble/_bagging.py:353: FutureWarning: `base_estimator` was renamed to `estimator` in version 0.10 and will be removed in 0.12.
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.96      0.80      0.87       239
#            1       0.33      0.75      0.46        32
#
#     accuracy                           0.79       271
#    macro avg       0.65      0.77      0.67       271
# weighted avg       0.89      0.79      0.82       271

# %% [markdown]
# # SVM Classifier with balanced weights

# %%
from sklearn import svm

def run_svm_model(X_train, X_test, y_train, y_test):
    # create a svm classifier
    clf = svm.SVC(kernel='rbf',C=1.0,random_state=1,class_weight='balanced') # rbf kernel
    # train the model using the training sets
    clf.fit(X_train, y_train)
    return clf

pred_y = run_svm_model(X_train,X_test,y_train,y_test).predict(X_test)
print_results(y_test, pred_y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.74      0.83       239
#            1       0.28      0.75      0.40        32
#
#     accuracy                           0.74       271
#    macro avg       0.62      0.74      0.62       271
# weighted avg       0.88      0.74      0.78       271

# %% [markdown]
# # SVM Classifier with Subsampling in the majority class

# %%
us = NearMiss(n_neighbors=3, version=2)
X_train_res, y_train_res = us.fit_resample(X_train, y_train)
print ("Distribution before resampling {}".format(Counter(y_train)))
print ("Distribution after resampling {}".format(Counter(y_train_res)))
pred_y=run_svm_model(X_train_res,X_test,y_train_res,y_test).predict(X_test)
print_results(y_test, pred_y)
# Out:
# Distribution before resampling Counter({0: 976, 1: 106})
# Distribution after resampling Counter({0: 106, 1: 106})
#               precision    recall  f1-score   support
#
#            0       0.83      0.14      0.24       239
#            1       0.11      0.78      0.19        32
#
#     accuracy                           0.22       271
#    macro avg       0.47      0.46      0.22       271
# weighted avg       0.74      0.22      0.24       271

# %% [markdown]
# # Random Forest Classifier with balanced weights

# %%
from sklearn.ensemble import RandomForestClassifier
def run_rf_model(X_train, X_test, y_train, y_test):
    # create a Gaussian Classifier
    rf_clf = RandomForestClassifier(n_estimators=100,random_state=1,class_weight='balanced')

    # train the model using the training sets y_pred=clf.predict(X_test)
    rf_clf.fit(X_train,y_train)
    return rf_clf

pred_y = run_rf_model(X_train,X_test,y_train,y_test).predict(X_test)
print_results(y_test, pred_y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       239
#            1       0.55      0.19      0.28        32
#
#     accuracy                           0.89       271
#    macro avg       0.72      0.58      0.61       271
# weighted avg       0.86      0.89      0.86       271

# %%
# Subsampling
us = NearMiss(n_neighbors=3, version=2)
X_train_res, y_train_res = us.fit_resample(X_train, y_train)
print ("Distribution before resampling {}".format(Counter(y_train)))
print ("Distribution after resampling {}".format(Counter(y_train_res)))
pred_y=run_rf_model(X_train_res,X_test,y_train_res,y_test).predict(X_test)
print_results(y_test, pred_y)
# Out:
# Distribution before resampling Counter({0: 976, 1: 106})
# Distribution after resampling Counter({0: 106, 1: 106})
#               precision    recall  f1-score   support
#
#            0       0.98      0.36      0.52       239
#            1       0.16      0.94      0.28        32
#
#     accuracy                           0.42       271
#    macro avg       0.57      0.65      0.40       271
# weighted avg       0.88      0.42      0.49       271

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
ss=StandardScaler()
X_train=ss.fit_transform(X_train)
X_test=ss.fit_transform(X_test)

from tensorflow import convert_to_tensor as ct
from tensorflow.keras import Sequential,utils
from tensorflow.keras.layers import Dense,Dropout

#Creating a pipeline
model = Sequential()

#1st hidden layer with input layer
model.add(Dense(units=100,activation="relu",input_dim=23))

#2nd hidden layer
model.add(Dense(units=60,activation="relu",))

#3rd hidden layer
model.add(Dense(units=12,activation="relu",))




#output layer
model.add(Dense(units=1,activation="sigmoid"))

model.summary()
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
model_his=model.fit(X_train,y_train,validation_split=0.20, batch_size=20,epochs=20,verbose=1)


y_pred=model.predict(X_test)
y_pred = (y_pred > 0.45)
print(classification_report(y_test,y_pred,zero_division=0))

import matplotlib.pyplot as plt
# summarize history for accuracy
plt.plot(model_his.history['accuracy'])
plt.plot(model_his.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


# summarize history for loss
plt.plot(model_his.history['loss'])
plt.plot(model_his.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_100 (Dense)           (None, 100)               2400
#
#  dense_101 (Dense)           (None, 60)                6060
#
#  dense_102 (Dense)           (None, 12)                732
#
#  dense_103 (Dense)           (None, 1)                 13
#
# =================================================================
# Total params: 9205 (35.96 KB)
# Trainable params: 9205 (35.96 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4566 - accuracy: 0.8694 - val_loss: 0.3604 - val_accuracy: 0.8940
# Epoch 2/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.2630 - accuracy: 0.9040 - val_loss: 0.3052 - val_accuracy: 0.8940
# Epoch 3/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.2166 - accuracy: 0.9087 - val_loss: 0.2862 - val_accuracy: 0.8986
# Epoch 4/50
# 44/44 [==============================] - 0s 3ms/step - loss: 0.1969 - accuracy: 0.9237 - val_loss: 0.3072 - val_accuracy: 0.8940
# Epoch 5/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1831 - accuracy: 0.9318 - val_loss: 0.3013 - val_accuracy: 0.8848
# Epoch 6/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1689 - accuracy: 0.9353 - val_loss: 0.3261 - val_accuracy: 0.8802
# Epoch 7/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1572 - accuracy: 0.9376 - val_loss: 0.3165 - val_accuracy: 0.8802
# Epoch 8/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1456 - accuracy: 0.9422 - val_loss: 0.3383 - val_accuracy: 0.8756
# Epoch 9/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1318 - accuracy: 0.9491 - val_loss: 0.3397 - val_accuracy: 0.8756
# Epoch 10/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1236 - accuracy: 0.9572 - val_loss: 0.3442 - val_accuracy: 0.8710
# Epoch 11/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1111 - accuracy: 0.9595 - val_loss: 0.3605 - val_accuracy: 0.8710
# Epoch 12/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1012 - accuracy: 0.9618 - val_loss: 0.3859 - val_accuracy: 0.8756
# Epoch 13/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0881 - accuracy: 0.9676 - val_loss: 0.3969 - val_accuracy: 0.8710
# Epoch 14/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0790 - accuracy: 0.9723 - val_loss: 0.4149 - val_accuracy: 0.8664
# Epoch 15/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0720 - accuracy: 0.9803 - val_loss: 0.4381 - val_accuracy: 0.8710
# Epoch 16/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0620 - accuracy: 0.9838 - val_loss: 0.5372 - val_accuracy: 0.8756
# Epoch 17/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0530 - accuracy: 0.9850 - val_loss: 0.5191 - val_accuracy: 0.8664
# Epoch 18/50
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0452 - accuracy: 0.9908 - val_loss: 0.5870 - val_accuracy: 0.8710
# Epoch 19/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0390 - accuracy: 0.9919 - val_loss: 0.6274 - val_accuracy: 0.8710
# Epoch 20/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0312 - accuracy: 0.9965 - val_loss: 0.6748 - val_accuracy: 0.8664
# Epoch 21/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0271 - accuracy: 0.9965 - val_loss: 0.6670 - val_accuracy: 0.8618
# Epoch 22/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0234 - accuracy: 0.9977 - val_loss: 0.7324 - val_accuracy: 0.8571
# Epoch 23/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0202 - accuracy: 0.9988 - val_loss: 0.7660 - val_accuracy: 0.8618
# Epoch 24/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0170 - accuracy: 0.9977 - val_loss: 0.8605 - val_accuracy: 0.8710
# Epoch 25/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0148 - accuracy: 0.9988 - val_loss: 0.8581 - val_accuracy: 0.8571
# Epoch 26/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0118 - accuracy: 0.9988 - val_loss: 0.9616 - val_accuracy: 0.8710
# Epoch 27/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0109 - accuracy: 0.9988 - val_loss: 0.9220 - val_accuracy: 0.8571
# Epoch 28/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0089 - accuracy: 0.9988 - val_loss: 0.9979 - val_accuracy: 0.8571
# Epoch 29/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 0.9988 - val_loss: 0.9775 - val_accuracy: 0.8571
# Epoch 30/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 0.9988 - val_loss: 1.0319 - val_accuracy: 0.8618
# Epoch 31/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 0.9988 - val_loss: 1.0627 - val_accuracy: 0.8618
# Epoch 32/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 0.9988 - val_loss: 1.1199 - val_accuracy: 0.8618
# Epoch 33/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 1.1217 - val_accuracy: 0.8571
# Epoch 34/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 1.1605 - val_accuracy: 0.8618
# Epoch 35/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 1.2060 - val_accuracy: 0.8618
# Epoch 36/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.2260 - val_accuracy: 0.8618
# Epoch 37/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0034 - accuracy: 0.9988 - val_loss: 1.2390 - val_accuracy: 0.8618
# Epoch 38/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 1.2610 - val_accuracy: 0.8618
# Epoch 39/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.3069 - val_accuracy: 0.8618
# Epoch 40/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.2926 - val_accuracy: 0.8618
# Epoch 41/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.3562 - val_accuracy: 0.8618
# Epoch 42/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.3849 - val_accuracy: 0.8618
# Epoch 43/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.3588 - val_accuracy: 0.8618
# Epoch 44/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.4251 - val_accuracy: 0.8618
# Epoch 45/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.4456 - val_accuracy: 0.8618
# Epoch 46/50
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.4831 - val_accuracy: 0.8618
# Epoch 47/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.4618 - val_accuracy: 0.8618
# Epoch 48/50
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.5212 - val_accuracy: 0.8618
# Epoch 49/50
# 44/44 [==============================] - 0s 1ms/step - loss: 8.6117e-04 - accuracy: 1.0000 - val_loss: 1.5051 - val_accuracy: 0.8618
# Epoch 50/50
# 44/44 [==============================] - 0s 1ms/step - loss: 7.3537e-04 - accuracy: 1.0000 - val_loss: 1.5518 - val_accuracy: 0.8618
# 9/9 [==============================] - 0s 600us/step
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       239
#            1       0.40      0.25      0.31        32
#
#     accuracy                           0.87       271
#    macro avg       0.65      0.60      0.62       271
# weighted avg       0.84      0.87      0.85       271
